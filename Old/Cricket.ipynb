# %%
import pandas as pd
import glob

# %%
class Ball(dict):
    # change to ordered dict
    def __init__(self):
        self['score'] = 0
        self['bat'] = 0
        self['wicket'] = None
        self['wide'] = True

# %%
b = Innings()

# %%
class Innings(Ball):
    
    def __init__(self):
        self.bat_order = []
        
    def balls(self):
        return [b for b in self.values() if isinstance(b, Ball)]
    
    def runs(self):
        return [b['score'] for b in self.balls()]
    
    def partnerships(self):
        return []
    
    def bat_score(self, batsman):        
        return sum(b['bat'] for b in self.balls() if (b['batsman'] == batsman))

    def bat_balls_faced(self, batsman):        
        return sum(1 for b in self.balls() if (b['batsman'] == batsman) & (b['wide']))
    
    def bat_scorecard(self):
        score_board = []
        for batsman in self.bat_order:
            runs = self.bat_score(batsman)
            balls = self.bat_balls_faced(batsman)
            score_board.append((batsman, runs, balls))
        
        sb = pd.DataFrame(data=score_board, columns=['Batsmen', 'Runs', 'Balls Faced'])

        total = ('Total', sum(self.runs()), len(self.balls()))
        extra = ('Extras', total[1] - sb['Runs'].sum(), total[2] - sb['Balls Faced'].sum())
        score_board.append(extra)
        score_board.append(total)

        return pd.DataFrame(data=score_board, columns=['Batsmen', 'Runs', 'Balls Faced'])

# %%
class Match(dict):    
    def __init__(self, match_id):
        self.match_id = match_id
        self.team = {}
        
    def bat_score(self, batsman):
        if batsman in self[1].bat_order:
            return self[1].bat_score(batsman)
        elif batsman in self[2].bat_order:
            return self[2].bat_score(batsman)
        else:
            return None           
        
    def winner(self):
        pass

# %%
class Player(dict):
    
    def __init__(self, name):
        self.name = name
        self.games = []
    
    def __repr__(self):
        return 'Bat Ave : {:0.1f}'.format(self.average())
    
    def total_runs(self):
        pass
    
    def average(self):
        # need to take into account not outs...
        total = [all_games[g].bat_score(self.name) for g in self.games]
        total = [i for i in total if i is not None]
        return sum(total) / len(total)

# %%
def read_match(match_id):

    game = Match(match_id)
    f = open('IPL/{:s}.yaml'.format(match_id), 'r')

    for line in f.readlines():
        tabs = [a.strip('\n') for a in line.split('  ')]
        len_tabs = len(tabs)
        try:
            var, out = [a.strip() for a in tabs[-1].split(':')]
        except:
            var = None
            out = [a.strip() for a in tabs[-1].split('- ')]

        if len_tabs == 2:
            game[var] = out
            if (var == '- 1st innings'): 
                innings = game[1] = Innings()
            if (var == '- 2nd innings'):
                innings = game[2] = Innings()

        if len_tabs == 5:
            current_ball = innings[var] = Ball()

        if len_tabs == 7:
            if var == 'wicket':
                current_ball['wicket'] = True
            else:
                current_ball[var] = out
            if var == 'batsman':
                if out not in innings.bat_order:
                    innings.bat_order.append(out)       

        if len_tabs == 8:
            if var == 'total':
                current_ball['score'] = int(out)
            if var == 'batsman':
                current_ball['bat'] = int(out)
            if (var == 'wides'):
                current_ball['wide'] = False
    return game

# %%
a = Match('335982')

# %%
a[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-3ef3908cabc7> in <module>()
# ----> 1 a[1]
#
# KeyError: 1

# %%
all_games = {}
all_batsmen = {}

for file_name in glob.glob('IPL/*.yaml'):
    match_id = file_name.strip('IPL/').strip('.yaml')
    print ('reading in match id {:s}'.format(match_id))
    curr_match = all_games[match_id] = read_match(match_id)
    
    for bat in curr_match[1].bat_order + curr_match[1].bat_order:
        if bat not in all_batsmen.keys():
            all_batsmen[bat] = Player(bat) 
        all_batsmen[bat].games.append(match_id)
# Out:
# reading in match id \335982
# reading in match id \335983
# reading in match id \335984
# reading in match id \335985
# reading in match id \335986
# reading in match id \335987
# reading in match id \335988
# reading in match id \335989
# reading in match id \335990
# reading in match id \335991
# reading in match id \335992
# reading in match id \335993
# reading in match id \335994
# reading in match id \335995
# reading in match id \335996
# reading in match id \335997
# reading in match id \335998
# reading in match id \335999
# reading in match id \336000
# reading in match id \336001
# reading in match id \336002
# reading in match id \336003
# reading in match id \336004
# reading in match id \336005
# reading in match id \336006
# reading in match id \336007
# reading in match id \336008
# reading in match id \336009
# reading in match id \336010
# reading in match id \336011
# reading in match id \336012
# reading in match id \336013
# reading in match id \336014
# reading in match id \336015
# reading in match id \336016
# reading in match id \336017
# reading in match id \336018
# reading in match id \336019
# reading in match id \336020
# reading in match id \336021
# reading in match id \336022
# reading in match id \336023
# reading in match id \336024
# reading in match id \336025
# reading in match id \336026
# reading in match id \336027
# reading in match id \336028
# reading in match id \336029
# reading in match id \336031
# reading in match id \336032
# reading in match id \336033
# reading in match id \336034
# reading in match id \336035
# reading in match id \336036
# reading in match id \336037
# reading in match id \336038
# reading in match id \336039
# reading in match id \336040
# reading in match id \392181
# reading in match id \392182
# reading in match id \392183
# reading in match id \392184
# reading in match id \392185
# reading in match id \392186
# reading in match id \392188
# reading in match id \392189
# reading in match id \392190
# reading in match id \392191
# reading in match id \392192
# reading in match id \392194
# reading in match id \392195
# reading in match id \392196
# reading in match id \392197
# reading in match id \392198
# reading in match id \392199
# reading in match id \392200
# reading in match id \392201
# reading in match id \392202
# reading in match id \392203
# reading in match id \392204
# reading in match id \392205
# reading in match id \392206
# reading in match id \392207
# reading in match id \392208
# reading in match id \392209
# reading in match id \392210
# reading in match id \392211
# reading in match id \392212
# reading in match id \392213
# reading in match id \392214
# reading in match id \392215
# reading in match id \392216
# reading in match id \392217
# reading in match id \392218
# reading in match id \392219
# reading in match id \392220
# reading in match id \392221
# reading in match id \392222
# reading in match id \392223
# reading in match id \392224
# reading in match id \392225
# reading in match id \392226
# reading in match id \392227
# reading in match id \392228
# reading in match id \392229
# reading in match id \392230
# reading in match id \392231
# reading in match id \392232
# reading in match id \392233
# reading in match id \392234
# reading in match id \392235
# reading in match id \392236
# reading in match id \392237
# reading in match id \392238
# reading in match id \392239
# reading in match id \419106
# reading in match id \419107
# reading in match id \419108
# reading in match id \419109
# reading in match id \419110
# reading in match id \419111
# reading in match id \419112
# reading in match id \419113
# reading in match id \419114
# reading in match id \419115
# reading in match id \419116
# reading in match id \419117
# reading in match id \419118
# reading in match id \419119
# reading in match id \419120
# reading in match id \419121
# reading in match id \419122
# reading in match id \419123
# reading in match id \419124
# reading in match id \419125
# reading in match id \419126
# reading in match id \419127
# reading in match id \419128
# reading in match id \419129
# reading in match id \419130
# reading in match id \419131
# reading in match id \419132
# reading in match id \419133
# reading in match id \419134
# reading in match id \419135
# reading in match id \419136
# reading in match id \419137
# reading in match id \419138
# reading in match id \419139
# reading in match id \419140
# reading in match id \419141
# reading in match id \419142
# reading in match id \419143
# reading in match id \419144
# reading in match id \419145
# reading in match id \419146
# reading in match id \419147
# reading in match id \419148
# reading in match id \419149
# reading in match id \419150
# reading in match id \419151
# reading in match id \419152
# reading in match id \419153
# reading in match id \419154
# reading in match id \419155
# reading in match id \419156
# reading in match id \419157
# reading in match id \419158
# reading in match id \419159
# reading in match id \419160
# reading in match id \419161
# reading in match id \419162
# reading in match id \419163
# reading in match id \419164
# reading in match id \419165
# reading in match id \501198
# reading in match id \501199
# reading in match id \501200
# reading in match id \501201
# reading in match id \501202
# reading in match id \501203
# reading in match id \501204
# reading in match id \501205
# reading in match id \501206
# reading in match id \501207
# reading in match id \501208
# reading in match id \501209
# reading in match id \501210
# reading in match id \501211
# reading in match id \501212
# reading in match id \501213
# reading in match id \501214
# reading in match id \501215
# reading in match id \501216
# reading in match id \501218
# reading in match id \501219
# reading in match id \501220
# reading in match id \501221
# reading in match id \501222
# reading in match id \501223
# reading in match id \501224
# reading in match id \501225
# reading in match id \501226
# reading in match id \501227
# reading in match id \501228
# reading in match id \501229
# reading in match id \501230
# reading in match id \501231
# reading in match id \501232
# reading in match id \501233
# reading in match id \501234
# reading in match id \501235
# reading in match id \501236
# reading in match id \501237
# reading in match id \501238
# reading in match id \501239
# reading in match id \501240
# reading in match id \501241
# reading in match id \501242
# reading in match id \501243
# reading in match id \501244
# reading in match id \501245
# reading in match id \501246
# reading in match id \501247
# reading in match id \501248
# reading in match id \501249
# reading in match id \501250
# reading in match id \501251
# reading in match id \501252
# reading in match id \501253
# reading in match id \501254
# reading in match id \501255
# reading in match id \501256
# reading in match id \501257
# reading in match id \501258
# reading in match id \501259
# reading in match id \501260
# reading in match id \501261
# reading in match id \501262
# reading in match id \501263
# reading in match id \501264
# reading in match id \501265
# reading in match id \501266
# reading in match id \501267
# reading in match id \501268
# reading in match id \501269
# reading in match id \501270
# reading in match id \501271
# reading in match id \548306
# reading in match id \548307
# reading in match id \548308
# reading in match id \548309
# reading in match id \548310
# reading in match id \548311
# reading in match id \548312
# reading in match id \548313
# reading in match id \548314
# reading in match id \548315
# reading in match id \548316
# reading in match id \548317
# reading in match id \548318
# reading in match id \548319
# reading in match id \548320
# reading in match id \548321
# reading in match id \548322
# reading in match id \548323
# reading in match id \548324
# reading in match id \548325
# reading in match id \548326
# reading in match id \548327
# reading in match id \548328
# reading in match id \548329
# reading in match id \548330
# reading in match id \548331
# reading in match id \548332
# reading in match id \548333
# reading in match id \548334
# reading in match id \548335
# reading in match id \548336
# reading in match id \548337
# reading in match id \548339
# reading in match id \548341
# reading in match id \548342
# reading in match id \548343
# reading in match id \548344
# reading in match id \548345
# reading in match id \548346
# reading in match id \548347
# reading in match id \548348
# reading in match id \548349
# reading in match id \548350
# reading in match id \548351
# reading in match id \548352
# reading in match id \548353
# reading in match id \548354
# reading in match id \548355
# reading in match id \548356
# reading in match id \548357
# reading in match id \548358
# reading in match id \548359
# reading in match id \548360
# reading in match id \548361
# reading in match id \548362
# reading in match id \548363
# reading in match id \548364
# reading in match id \548365
# reading in match id \548366
# reading in match id \548367
# reading in match id \548368
# reading in match id \548369
# reading in match id \548370
# reading in match id \548371
# reading in match id \548372
# reading in match id \548373
# reading in match id \548374
# reading in match id \548375
# reading in match id \548376
# reading in match id \548377
# reading in match id \548378
# reading in match id \548379
# reading in match id \548380
# reading in match id \548381
# reading in match id \597998
# reading in match id \597999
# reading in match id \598000
# reading in match id \598001
# reading in match id \598002
# reading in match id \598003
# reading in match id \598004
# reading in match id \598005
# reading in match id \598006
# reading in match id \598007
# reading in match id \598008
# reading in match id \598009
# reading in match id \598010
# reading in match id \598011
# reading in match id \598012
# reading in match id \598013
# reading in match id \598014
# reading in match id \598015
# reading in match id \598016
# reading in match id \598017
# reading in match id \598018
# reading in match id \598019
# reading in match id \598020
# reading in match id \598021
# reading in match id \598022
# reading in match id \598023
# reading in match id \598024
# reading in match id \598025
# reading in match id \598026
# reading in match id \598027
# reading in match id \598028
# reading in match id \598029
# reading in match id \598030
# reading in match id \598031
# reading in match id \598032
# reading in match id \598033
# reading in match id \598034
# reading in match id \598035
# reading in match id \598036
# reading in match id \598037
# reading in match id \598038
# reading in match id \598039
# reading in match id \598040
# reading in match id \598041
# reading in match id \598042
# reading in match id \598043
# reading in match id \598044
# reading in match id \598045
# reading in match id \598046
# reading in match id \598047
# reading in match id \598048
# reading in match id \598049
# reading in match id \598050
# reading in match id \598051
# reading in match id \598052
# reading in match id \598053
# reading in match id \598054
# reading in match id \598055
# reading in match id \598056
# reading in match id \598057
# reading in match id \598058
# reading in match id \598059
# reading in match id \598060
# reading in match id \598061
# reading in match id \598062
# reading in match id \598063
# reading in match id \598064
# reading in match id \598065
# reading in match id \598066
# reading in match id \598067
# reading in match id \598068
# reading in match id \598069
# reading in match id \598070
# reading in match id \598071
# reading in match id \598072
# reading in match id \598073
# reading in match id \729279
# reading in match id \729281
# reading in match id \729283
# reading in match id \729285
# reading in match id \729287
# reading in match id \729289
# reading in match id \729291
# reading in match id \729293
# reading in match id \729295
# reading in match id \729297
# reading in match id \729299
# reading in match id \729301
# reading in match id \729303
# reading in match id \729305
# reading in match id \729307
# reading in match id \729309
# reading in match id \729311
# reading in match id \729313
# reading in match id \729315
# reading in match id \729317
# reading in match id \733971
# reading in match id \733973
# reading in match id \733975
# reading in match id \733977
# reading in match id \733979
# reading in match id \733981
# reading in match id \733983
# reading in match id \733985
# reading in match id \733987
# reading in match id \733989
# reading in match id \733991
# reading in match id \733993
# reading in match id \733995
# reading in match id \733997
# reading in match id \733999
# reading in match id \734001
# reading in match id \734003
# reading in match id \734005
# reading in match id \734007
# reading in match id \734009
# reading in match id \734011
# reading in match id \734013
# reading in match id \734015
# reading in match id \734017
# reading in match id \734019
# reading in match id \734021
# reading in match id \734023
# reading in match id \734025
# reading in match id \734027
# reading in match id \734029
# reading in match id \734031
# reading in match id \734033
# reading in match id \734035
# reading in match id \734037
# reading in match id \734039
# reading in match id \734041
# reading in match id \734043
# reading in match id \734045
# reading in match id \734047
# reading in match id \734049
# reading in match id \829705
# reading in match id \829707
# reading in match id \829709
# reading in match id \829711
# reading in match id \829713
# reading in match id \829715
# reading in match id \829717
# reading in match id \829719
# reading in match id \829721
# reading in match id \829723
# reading in match id \829725
# reading in match id \829727
# reading in match id \829729
# reading in match id \829731
# reading in match id \829733
# reading in match id \829735
# reading in match id \829737
# reading in match id \829739
# reading in match id \829741
# reading in match id \829743
# reading in match id \829745
# reading in match id \829747
# reading in match id \829749
# reading in match id \829751
# reading in match id \829753
# reading in match id \829757
# reading in match id \829759
# reading in match id \829761
# reading in match id \829763
# reading in match id \829765
# reading in match id \829767
# reading in match id \829769
# reading in match id \829771
# reading in match id \829773
# reading in match id \829775
# reading in match id \829777
# reading in match id \829779
# reading in match id \829781
# reading in match id \829783
# reading in match id \829785
# reading in match id \829787
# reading in match id \829789
# reading in match id \829791
# reading in match id \829793
# reading in match id \829795
# reading in match id \829797
# reading in match id \829799
# reading in match id \829801
# reading in match id \829803
# reading in match id \829805
# reading in match id \829807
# reading in match id \829809
# reading in match id \829811
# reading in match id \829813
# reading in match id \829815
# reading in match id \829817
# reading in match id \829819
# reading in match id \829821
# reading in match id \829823
# reading in match id \980901
# reading in match id \980903
# reading in match id \980905
# reading in match id \980907
# reading in match id \980909
# reading in match id \980911
# reading in match id \980913
# reading in match id \980915
# reading in match id \980917
# reading in match id \980919
# reading in match id \980921
# reading in match id \980923
# reading in match id \980925
# reading in match id \980927
# reading in match id \980929
# reading in match id \980931
# reading in match id \980933
# reading in match id \980935
# reading in match id \980937
# reading in match id \980939
# reading in match id \980941
# reading in match id \980943
# reading in match id \980945
# reading in match id \980947
# reading in match id \980949
# reading in match id \980951
# reading in match id \980953
# reading in match id \980955
# reading in match id \980957
# reading in match id \980959
# reading in match id \980961
# reading in match id \980963
# reading in match id \980965
# reading in match id \980967
# reading in match id \980969
# reading in match id \980971
# reading in match id \980973
# reading in match id \980975
# reading in match id \980977
# reading in match id \980979
# reading in match id \980981
# reading in match id \980983
# reading in match id \980985
# reading in match id \980987
# reading in match id \980989
# reading in match id \980991
# reading in match id \980993
# reading in match id \980995
# reading in match id \980997
# reading in match id \980999
# reading in match id \981001
# reading in match id \981003
# reading in match id \981005
# reading in match id \981007
# reading in match id \981009
# reading in match id \981011
# reading in match id \981013
# reading in match id \981015
# reading in match id \981017
# reading in match id \981019

# %%
all_batsmen['A Flintoff']
# Out:
# Bat Ave : 22.0

# %%
all_games['\\335982'].bat_score('BB McCullum')
# Out:
# 158

# %%
all_games['\\335982'][1].bat_scorecard()
# Out:
#            Batsmen  Runs  Balls Faced
# 0       SC Ganguly    10           12
# 1      BB McCullum   158           73
# 2       RT Ponting    20           20
# 3        DJ Hussey    12           12
# 4  Mohammad Hafeez     5            3
# 5           Extras    17            4
# 6            Total   222          124

# %%
sb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-864f8ab9f984> in <module>()
# ----> 1 sb
#
# NameError: name 'sb' is not defined
